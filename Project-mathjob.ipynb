# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

from fnmatch import fnmatch

import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from pattern import web


# set some nicer defaults for matplotlib
from matplotlib import rcParams


# Mathjobs job page
url = "https://www.mathjobs.org/jobs?joblist-0-3----t"

job_page = requests.get(url).text.encode('ascii', 'ignore')

def is_jobs(l):
    """return True if this content include a job code"""    
    pattern = '*[*'
    return fnmatch(l, pattern)

def extractalljobs(html):
    dom = web.Element(html)
#    result_headers=['Index', 'Code','Institute','Title','url']
    
    Index = []
    Code = []
    Inst = []
    Title = []
    URL = []
    
    location = []
    subject = []
    deadline = []
    
    i = 0
    
    for listing in dom.by_tag('dl'):

        Index.append(i)
        for jobs in listing.by_tag('li'):
            job_content=jobs.content.encode('ascii','ignore')
            
            if is_jobs(job_content):
                i = i + 1
                Code.append(jobs.by_tag('a')[0].content.encode('ascii','ignore'))
                Inst.append(listing.by_tag('b')[0].by_tag('a')[0].content.encode('ascii','ignore')) #remove the 'u in school name
                m = re.search('] (.+?)&nbsp', job_content)
                if m:
                    Title.append(m.group(1).replace('<i>','').replace('</i>',''))                     
                URL.append(jobs.by_tag('a')[0].attributes.get('href', '')) 
                
    URL = ["http://www.mathjobs.org"+l for l in URL]   
    URL = [x.encode('UTF8') for x in URL]
    
    for url in URL:
        jobinfo=extractsinglejob(url)
        location.append(jobinfo['location'])
        subject.append(jobinfo['subject'])
        deadline.append(jobinfo['deadline'])
                        
    result = pd.DataFrame({'Index': range(1,i+1), 'Code': Code, 'Institution': Inst, 'Title': Title, 
                           'URL': URL, 'Location':location, 'Subject': subject, 'Deadline': deadline})
    return result


# The following routine read a url of a specific job and extract the research field, location, deadline, etc. 
def extractsinglejob(url):
    myjob = requests.get(url).text.encode('ascii', 'ignore')
    dom = web.Element(myjob)
    
    m = re.search('Position Location(.+)<a', str(dom))
    if m:
        location = m.group(1).replace(':</b> ','').replace(' [','')
    else:
        location = 'nan'            
        
    m = re.search('Subject Area(.+)<br', str(dom))
    if m:
        subject = m.group(1).replace(':</b> ','').replace(' [','')
    else:
        subject = 'nan'
    
    m = re.search('Application Deadline(.+)<br', str(dom))
    if m:
        deadline = m.group(1).replace(':</b> ','').replace(' [','')
    else:
        deadline = 'nan'

    result = {'location': location, 'subject': subject, 'deadline': deadline}
    
    return result
    
DF = extractalljobs(job_page)
NewDeadline = [DF.Deadline[j].split('  (')[0] for j in DF.index]
DF.Deadline = NewDeadline
DF_sorted=DF.sort("Deadline") # Sort jobs by deadline

# %%
from sqlalchemy.types import String
from sqlalchemy import create_engine

engine = create_engine('sqlite:///:memory:')

DF.to_sql('mathjoblisting',engine,index=False)

qq ='''SELECT Code,Deadline,Institution,Title FROM mathjoblisting 
Where Deadline BETWEEN 2015 AND 2017 ORDER BY Deadline ASC'''

pd.read_sql_query(qq, engine) # Show jobs under certain condition using SQL engine
# Out:
#                  Code     Deadline  \
# 0                 PDF   2015/07/21
# 1              CDSEPD   2015/10/15
# 2    POSTDOCPOSITIONS   2015/11/01
# 3             PDF2015   2015/11/01
# 4       CARRIERFELLOW   2015/11/15
# 5      NEUKFELLOW1616   2015/11/15
# 6               PDFRF   2015/11/15
# 7               PDF16   2015/11/15
# 8           PIMSPDF16   2015/11/15
# 9              SLIM15   2015/11/15
# 10            POSTDOC   2015/11/15
# 11            POSTDOC   2015/11/15
# 12                 PF  2015/11/15*
# 13             RAPZAP   2015/11/16
# 14            PIMSPDF   2015/11/16
# 15                PRF   2015/11/20
# 16                PDF   2015/11/20
# 17            POSTDOC   2015/11/20
# 18                 PD   2015/11/22
# 19            POSTDOC   2015/11/24
# 20            POSTDOC   2015/11/30
# 21         RTGPOSTDOC   2015/11/30
# 22               PDSA   2015/11/30
# 23                 PA   2015/11/30
# 24                PDA   2015/11/30
# 25             PD2016   2015/11/30
# 26            POSTDOC   2015/12/01
# 27               PD16   2015/12/01
# 28           HSIUNGVP   2015/12/01
# 29             INST16   2015/12/01
# ..                ...          ...
# 59         STOCHASTIC   2015/12/15
# 60           VVAP2016   2015/12/15
# 61            IMS2016  2015/12/15*
# 62             PD2016  2015/12/15*
# 63                 RF   2015/12/20
# 64              HMSPD   2015/12/31
# 65       MM_VAP_F2015   2015/12/31
# 66               PD16   2015/12/31
# 67     GEOMATHEMATICS   2015/12/31
# 68            HAP1516   2015/12/31
# 69                PDF   2016/01/01
# 70            POSTDOC   2016/01/01
# 71  INDUSTRIALPOSTDOC  2016/01/01*
# 72     REGULARPOSTDOC  2016/01/01*
# 73                PDF   2016/01/04
# 74            PDF1516   2016/01/06
# 75            POSTDOC   2016/01/08
# 76              CNAPD   2016/01/15
# 77           SIMONSPD   2016/01/31
# 78               PRFR   2016/01/31
# 79          PDSCHOLAR   2016/01/31
# 80               SWIF   2016/02/01
# 81            POSTDOC   2016/02/01
# 82               DJ16   2016/02/25
# 83                PDA   2016/02/29
# 84                 PD   2016/03/03
# 85       POSTDOCTORAT   2016/03/31
# 86                PTG   2016/03/31
# 87              PMC16   2016/08/31
# 88         POSTDOCRES   2016/09/30
#
#                                           Institution  \
# 0                             University of Newcastle
# 1            Mathematics, University at Buffalo, SUNY
# 2   Hausdorff Center for Mathematics, University o...
# 3   Institute for Quantum Computing, University of...
# 4   School of Engineering and Applied Science, Har...
# 5          Neukom Institute for Computational Science
# 6   Mathematical Sciences Institute, The Australia...
# 7   Department of Mathematics, University of Briti...
# 8   Department of Mathematics, University of Briti...
# 9   Department of Mathematics, University of Briti...
# 10  Institute for Mathematics and Scientific Compu...
# 11  Department of Mathematics, University of Manitoba
# 12  Mathematics and Statistics, University of Vict...
# 13                 Mathematics, Ohio State University
# 14  Department of Mathematics and Statistics, Univ...
# 15                    MEC, The University of Adelaide
# 16  Mathematical and Statistical Sciences, Univers...
# 17  Applied Mathematics and Statistics, University...
# 18              Mathematics, Universidad de los Andes
# 19      Beijing Computational Science Research Center
# 20  School of Mathematical and Statistical Science...
# 29                                            INST-16
# ..                                                ...
# 59  Stochastic Modelling of Energy Markets, Postdo...
# 60    various, Van Vleck Visiting Assistant Professor
# 61                  Milnor Lecturer Faculty Positions
# 62               Simons Instructors Faculty Positions
# 63          Mathematics, Postdoctoral Research Fellow
# 64  Postdoctoral Researcher in Homological Mirror ...
# 65          Mathematics, Visiting Assistant Professor
# 66                         Mathematics, Post Doc 2016
# 67  Geomathematics, Postdoctoral Positions - Alber...
# 68  Mathematics / Applied Mathematics, Hildebrandt...
# 69  Data Science, Data Science Post-Doctoral Fello...
# 70               Mathematics, Postdoctoral Fellowship
# 71             IMA Industrial Postdoctoral Fellowship
# 72  Mathematics and Optics, IMA Postdoctoral Fello...
# 73               Mathematics, Postdoctoral Fellowship
# 74  Computational Engineering, Scientific and Math...
# 75  differential geometry, Postdoctoral research f...
# 76           Applied Analysis, Postdoctoral Associate
# 77  Homological mirror symmetry and its applicatio...
# 78  All mathematical disciplines, Postdoctoral Res...
# 79  Postdoc (scholarships) in geometric PDEs and m...
# 80  Singularities and Waves In Incompressible Flui...
# 81  Postdoctoral Positions at Beijing Internationa...
# 82            DUNHAM JACKSON (DJ) ASSISTANT PROFESSOR
# 83          Computational topology, Postdoc Associate
# 84  Mathematics, Postdoc (Visiting Assistant Profe...
# 85  pure mathematics,applied PDE,computational mat...
# 86                Topology/Geometry, Postdoc-Topology
# 87                Peter M. Curran Research Instructor
# 88                            Postdoctoral Researcher
#
# [89 rows x 4 columns]

# %%
DF.head()
# Out:
#          Code    Deadline  Index  \
# 0     POSTDOC  2015/11/30      1
# 1  RTGPOSTDOC  2015/11/30      2
# 2     POSTDOC                  3
# 3     POSTDOC  2015/12/01      4
# 4     POSTDOC  2015/11/24      5
#
#                                          Institution  \
# 0  School of Mathematical and Statistical Science...
# 1  School of Mathematical and Statistical Science...
# 2      Mathematics and Statistics, Auburn University
# 3       Department of Mathematics, Baylor University
# 4      Beijing Computational Science Research Center
#
#                                           Location  \
# 0         Tempe, Arizona 85287-1804, United States
# 1         Tempe, Arizona 85287-1804, United States
# 2  Auburn University, Alabama 36849, United States
# 3                 Waco, Texas Texas, United States
# 4                   Beijing, Beijing 100084, China
#
#                                              Subject  \
# 0  all areas in mathematical and statistical scie...
# 1                 Applied Mathematics and Statistics
# 2                     sMathematics and/or Statistics
# 3              areas compatible with current faculty
# 4                              computational science
#
#                                                Title  \
# 0  all areas in mathematical and statistical scie...
# 1  Applied Mathematics and Statistics, Postdoctor...
# 2  Mathematics and/or Statistics, PostDoctoral Fe...
# 3  areas compatible with current faculty, Post Do...
# 4  computational science, Postdoc Positions (5+) ...
#
#                                       URL
# 0  http://www.mathjobs.org/jobs/jobs/7645
# 1  http://www.mathjobs.org/jobs/jobs/7644
# 2  http://www.mathjobs.org/jobs/jobs/7923
# 3  http://www.mathjobs.org/jobs/jobs/7682
# 4  http://www.mathjobs.org/jobs/jobs/6779
